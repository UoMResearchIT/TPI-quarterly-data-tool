# %%
import pandas as pd
import plotly.express as px

# %%
dataset = pd.read_csv("../out/Dataset.csv")
print(dataset)
# Out:
#      Quarter  ONS GVA     ONS OPH    ONS OPW    ONS OPJ  US hours worked  \
# 0    1997 Q1     62.4   74.687601  77.913929  77.222599           89.424
# 1    1997 Q2     63.0   75.004554  78.266623  77.598077           89.857
# 2    1997 Q3     63.4   75.400975  78.673868  77.947740           90.392
# 3    1997 Q4     64.3   76.479813  79.576542  78.958569           90.822
# 4    1998 Q1     64.8   76.727021  80.102171  79.519103           91.392
# ..       ...      ...         ...        ...        ...              ...
# 104  2023 Q3    100.3  100.080860  99.211469  99.474887          105.473
# 105  2023 Q4    100.1   99.223607  98.795586  99.066119          105.535
# 106  2024 Q1    100.8   98.829858  99.664105  99.853851          105.696
# 107  2024 Q2    101.2   98.631241  99.522966  99.466030          105.936
# 108  2024 Q3    101.2   97.636412  98.804243  98.835731          106.247
#
#      US real value-added output   US OPW  Germany OPH  \
# ...

# %%
fig = px.line(dataset, x="Quarter", y=["ONS OPW", "US OPW", "Germany OPW", "Italy OPW", "Spain OPW", "France OPW"], title="Time Series Comparison")
fig.show()
